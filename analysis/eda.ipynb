# %% [markdown]
# <a href="https://colab.research.google.com/github/auto-d/k8s-taxi/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_parquet("../week3/data/demand_enriched_corrupted.parquet")

# %%
df.head()
# Out:
#    PULocationID         time_bucket  trip_count  hour  minute  dayofweek  \
# 0             4 2023-01-01 00:00:00           1     0       0          6
# 1             4 2023-01-01 00:15:00           4     0      15          6
# 2             4 2023-01-01 00:30:00           4     0      30          6
# 3             4 2023-01-01 00:45:00           5     0      45          6
# 4             4 2023-01-01 01:00:00           4     1       0          6
#
#    is_weekend  month  dayofyear  weekofyear  ...  is_airport_zone  \
# 0           1      1          1          52  ...                0
# 1           1      1          1          52  ...                0
# 2           1      1          1          52  ...                0
# 3           1      1          1          52  ...                0
# 4           1      1          1          52  ...                0
#
#    zone_slot_baseline  lag_15min  lag_1h  lag_2h  lag_1day  lag_1week  \
# ...

# %%
import seaborn as sns

# %%
CUTOFF = pd.Timestamp("2026-01-16")

baseline = df[df['time_bucket'] < CUTOFF]   # clean historical window
corrupted = df[df['time_bucket'] >= CUTOFF]  # new potentially corrupted window

print(f"Baseline: {len(baseline)} rows")
print(f"Corrupted: {len(corrupted)} rows")
print(f"\nBaseline columns: {baseline.columns.tolist()}")
print(f"\nBaseline null rates:\n{baseline.isna().mean()}")
print(f"\nCorrupted null rates:\n{corrupted.isna().mean()}")
# Out:
# Baseline: 6079392 rows
# Corrupted: 250853 rows
#
# Baseline columns: ['PULocationID', 'time_bucket', 'trip_count', 'hour', 'minute', 'dayofweek', 'is_weekend', 'month', 'dayofyear', 'weekofyear', 'year', 'slot_of_day', 'hour_sin', 'hour_cos', 'dow_sin', 'dow_cos', 'month_sin', 'month_cos', 'is_holiday', 'cbd_pricing_active', 'borough_id', 'service_zone_id', 'is_airport_zone', 'zone_slot_baseline', 'lag_15min', 'lag_1h', 'lag_2h', 'lag_1day', 'lag_1week', 'roll_mean_1h', 'roll_mean_2h', 'roll_mean_1day']
#
# Baseline null rates:
# PULocationID          0.000000
# time_bucket           0.000000
# trip_count            0.000000
# hour                  0.000000
# minute                0.000000
# dayofweek             0.000000
# is_weekend            0.000000
# month                 0.000000
# dayofyear             0.000000
# weekofyear            0.000000
# year                  0.000000
# slot_of_day           0.000000
# hour_sin              0.000000
# hour_cos              0.000000
# ...

# %%
baseline.columns == corrupted.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
a = set(baseline.columns)
b = set(corrupted.columns)

# %%
a == b
# Out:
# True

# %%
b.remove('month')

# %%
len(a.difference(b))
# Out:
# 1

# %%
baseline.isna().value_counts()
# Out:
# PULocationID  time_bucket  trip_count  hour   minute  dayofweek  is_weekend  month  dayofyear  weekofyear  year   slot_of_day  hour_sin  hour_cos  dow_sin  dow_cos  month_sin  month_cos  is_holiday  cbd_pricing_active  borough_id  service_zone_id  is_airport_zone  zone_slot_baseline  lag_15min  lag_1h  lag_2h  lag_1day  lag_1week  roll_mean_1h  roll_mean_2h  roll_mean_1day
# False         False        False       False  False   False      False       False  False      False       False  False        False     False     False    False    False      False      False       False               False       False            False            False               False      False   False   False     False      False         False         False             6041088
# ...

# %%
corrupted.isna().value_counts()
# Out:
# PULocationID  time_bucket  trip_count  hour   minute  dayofweek  is_weekend  month  dayofyear  weekofyear  year   slot_of_day  hour_sin  hour_cos  dow_sin  dow_cos  month_sin  month_cos  is_holiday  cbd_pricing_active  borough_id  service_zone_id  is_airport_zone  zone_slot_baseline  lag_15min  lag_1h  lag_2h  lag_1day  lag_1week  roll_mean_1h  roll_mean_2h  roll_mean_1day
# False         False        False       False  False   False      False       False  False      False       False  False        False     False     False    False    False      False      False       False               False       False            False            False               False      False   False   False     False      False         False         False             250853
# Name: count, dtype: int64

# %%
# check the ratio of the statustics of the baseline and corrupted dfs to find outliers and major deviations
b_details = baseline.describe()
c_details = corrupted.describe()

for col in baseline.columns:
  print(col)
  details = pd.concat([b_details[col], c_details[col]], axis=1)
  for idx, (v1, v2) in details.iterrows():
    try:
      print(f"{idx}: \t{(abs(v1 - v2)/(v1+0.000001)):.2}")
    except TypeError as e:
      print(e)
# Out:
# PULocationID
# count: 	0.96
# mean: 	0.014
# min: 	0.0
# 25%: 	0.011
# 50%: 	0.007
# 75%: 	0.0
# max: 	0.0
# std: 	0.012
# time_bucket
# count: 	0.96
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# unsupported operand type(s) for +: 'Timestamp' and 'float'
# std: 	nan
# trip_count
# count: 	0.96
# mean: 	3.6
# min: 	5e+06
# 25%: 	0.5
# 50%: 	0.33
# 75%: 	0.24
# max: 	3.2e+02
# std: 	1.1e+02
# hour
# count: 	0.96
# mean: 	2e-05
# min: 	0.0
# 25%: 	0.043
# 50%: 	0.043
# 75%: 	0.043
# max: 	0.0
# std: 	1.9e-05
# minute
# count: 	0.96
# mean: 	2e-05
# min: 	0.0
# 25%: 	0.33
# 50%: 	0.33
# 75%: 	0.33
# max: 	0.0
# std: 	9.9e-06
# dayofweek
# count: 	0.96
# mean: 	0.023
# min: 	0.0
# 25%: 	0.0
# 50%: 	0.0
# 75%: 	0.0
# max: 	0.0
# ...

# %%
baseline.describe()
# Out:
#        PULocationID                    time_bucket    trip_count  \
# count  6.079392e+06                        6079392  6.079392e+06
# mean   1.456140e+02  2024-07-09 11:52:29.999988736  1.703395e+01
# min    4.000000e+00            2023-01-01 00:00:00  0.000000e+00
# 25%    8.800000e+01            2023-10-05 17:56:15  2.000000e+00
# 50%    1.430000e+02            2024-07-09 11:52:30  9.000000e+00
# 75%    2.110000e+02            2025-04-13 05:48:45  2.500000e+01
# max    2.630000e+02            2026-01-15 23:45:00  3.100000e+02
# std    7.191169e+01                            NaN  2.157228e+01
#
#                hour        minute     dayofweek    is_weekend         month  \
# count  6.079392e+06  6.079392e+06  6.079392e+06  6.079392e+06  6.079392e+06
# mean   1.150000e+01  2.250000e+01  2.997300e+00  2.853285e-01  6.447345e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %%
corrupted.describe()
# Out:
#         PULocationID                    time_bucket     trip_count  \
# count  250853.000000                         250853  250853.000000
# mean      143.539005  2026-02-07 10:57:57.438580224      78.672804
# min         4.000000            2026-01-16 00:00:00      -5.000000
# 25%        87.000000            2026-01-27 11:00:00       1.000000
# 50%       142.000000            2026-02-07 22:00:00       6.000000
# 75%       211.000000            2026-02-18 11:00:00      19.000000
# max       263.000000            2026-02-28 23:45:00   99999.000000
# std        72.804804                            NaN    2433.026184
#
#                 hour         minute      dayofweek     is_weekend  \
# count  250853.000000  250853.000000  250853.000000  250853.000000
# mean       11.500229      22.500448       3.065481       0.295077
# min         0.000000       0.000000       0.000000       0.000000
# 25%         6.000000      15.000000       1.000000       0.000000
# ...

# %% [markdown]
# Review of the above ...
# - null values
# - data types
#   - validate what's being reported
#   attempt to recover or cull
# - numeric values
#   - we are running a tree model, i don't think independence or linearity are conerns
#   - negatives values present in trip_count
#   look at thedistrubtion of valuues
#     - corrupted tripcount histogram has absurdly large range, must be some erroneous high values
#     - perhaps gaps in weekofyear for the corrupted set, even though it should have continuous data
#     - what are month_sin, month_cos value

# %%
corrupted.describe()['hour']['min']
# Out:
# 0.0

# %%
for i in zip(baseline.dtypes, corrupted.dtypes):
  print(i[0]==i[1], i)
# Out:
# True (dtype('int64'), dtype('int64'))
# True (dtype('<M8[ns]'), dtype('<M8[ns]'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int8'), dtype('int8'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int64'), dtype('int64'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('int32'), dtype('int32'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('float64'), dtype('float64'))
# True (dtype('int8'), dtype('int8'))
# True (dtype('int8'), dtype('int8'))
# True (dtype('int64'), dtype('int64'))
# True (dtype('int64'), dtype('int64'))
# True (dtype('int8'), dtype('int8'))
# True (dtype('float64'), dtype('float64'))
# ...

# %%
corrupted[corrupted.trip_count < 0]
# Out:
#          PULocationID         time_bucket  trip_count  hour  minute  \
# 107155              4 2026-01-21 04:45:00          -1     4      45
# 107772              4 2026-01-27 15:00:00          -1    15       0
# 108067              4 2026-01-30 16:45:00          -1    16      45
# 110216              4 2026-02-22 02:00:00          -5     2       0
# 110329              4 2026-02-23 06:15:00          -5     6      15
# ...               ...                 ...         ...   ...     ...
# 6326569           107 2026-02-11 17:15:00          -1    17      15
# 6326619           107 2026-02-12 05:45:00          -1     5      45
# 6327219           107 2026-02-18 11:45:00          -1    11      45
# 6327946           107 2026-02-26 01:30:00          -1     1      30
# 6328013           107 2026-02-26 18:15:00          -5    18      15
#
#          dayofweek  is_weekend  month  dayofyear  weekofyear  ...  \
# 107155           2           0      1         21           4  ...
# ...

# %%
corrupted[corrupted.trip_count > baseline.trip_count.max()]
# Out:
#          PULocationID         time_bucket  trip_count  hour  minute  \
# 107451              4 2026-01-24 06:45:00        9999     6      45
# 107853              4 2026-01-28 11:15:00        9999    11      15
# 108054              4 2026-01-30 13:30:00        9999    13      30
# 110610              4 2026-02-26 04:30:00       99999     4      30
# 110615              4 2026-02-26 05:45:00        9999     5      45
# ...               ...                 ...         ...   ...     ...
# 6323554            43 2026-02-22 08:00:00       99999     8       0
# 6324135            43 2026-02-28 09:15:00        9999     9      15
# 6326255           107 2026-02-08 10:45:00        9999    10      45
# 6328248           229 2026-02-08 04:45:00       99999     4      45
# 6328907           229 2026-02-15 01:30:00        9999     1      30
#
#          dayofweek  is_weekend  month  dayofyear  weekofyear  ...  \
# 107451           5           1      1         24           4  ...
# ...

# %% [markdown]
# Validation based on above:
# - column presence -> critical if not, abort
# - additional columns -> warn
# - range checks +/- 20% based on baseline (for numerical values) -> drop offending columns and warn
# - duplicate IDs present?  -> drop offending rows and warn

# %%
len(baseline.index.unique()) == len(baseline)
# Out:
# True

# %%
len(corrupted.index.unique()) == len(corrupted)
# Out:
# True

# %%
len(corrupted) - len(corrupted.index.unique())
# Out:
# 0

# %%
baseline[baseline.time_bucket.isna()]
# Out:
# Empty DataFrame
# Columns: [PULocationID, time_bucket, trip_count, hour, minute, dayofweek, is_weekend, month, dayofyear, weekofyear, year, slot_of_day, hour_sin, hour_cos, dow_sin, dow_cos, month_sin, month_cos, is_holiday, cbd_pricing_active, borough_id, service_zone_id, is_airport_zone, zone_slot_baseline, lag_15min, lag_1h, lag_2h, lag_1day, lag_1week, roll_mean_1h, roll_mean_2h, roll_mean_1day]
# Index: []
#
# [0 rows x 32 columns]

# %%
baseline.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 6315931    False
# 6315932    False
# 6315933    False
# 6315934    False
# 6315935    False
# Length: 6079392, dtype: bool

# %%
corrupted.duplicated().value_counts()[1]
# Out:
# /var/folders/t0/vjz2r6l1155639x6cpfr8z3h0000gn/T/ipykernel_96505/356436327.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   corrupted.duplicated().value_counts()[1]
# 8134

# %%
dedup = corrupted[~corrupted.duplicated()]

# %%
len(corrupted)
# Out:
# 250853

# %%
len(dedup)
# Out:
# 242719

# %%
if not corrupted.index.is_unique: 
    corrupted.reset_index()

# %%
for col, val in baseline.isna().sum().items(): 
    print(col, val)
# Out:
# PULocationID 0
# time_bucket 0
# trip_count 0
# hour 0
# minute 0
# dayofweek 0
# is_weekend 0
# month 0
# dayofyear 0
# weekofyear 0
# year 0
# slot_of_day 0
# hour_sin 0
# hour_cos 0
# dow_sin 0
# dow_cos 0
# month_sin 0
# month_cos 0
# is_holiday 0
# cbd_pricing_active 0
# borough_id 0
# service_zone_id 0
# is_airport_zone 0
# zone_slot_baseline 0
# lag_15min 57
# lag_1h 228
# lag_2h 456
# lag_1day 5472
# lag_1week 38304
# roll_mean_1h 57
# roll_mean_2h 57
# roll_mean_1day 57

# %%
for row in corrupted.isna().sum().iterrows(): 
    print(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 for row in corrupted.isna().sum().iterrows():
#       2     print(row)
#
# File ~/Local/school/561/k8s-taxi/venv/lib/python3.12/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
baseline.duplicated().sum()
# Out:
# 0

# %%
b_stats = baseline.describe()
key_numeric_cols = [ 
    "trip_count", 
    "hour", 
    "minute", 
    "month", 
    "year",
]

n_stats = corrupted.describe()

for col in key_numeric_cols: 
    
    if not hasattr(n_stats, col): 
        print(f"Missing key column: {col}")
        continue

    min = b_stats[col]['min']
    if n_stats[col]['min'] < min:                 
        print(f"Minimum for {col} below baseline data")

    max = b_stats[col]['max']
    if n_stats[col]['max'] > max:                 
        print(f"Minimum for {col} above baseline data")
# Out:
# Minimum for trip_count below baseline data
# Minimum for trip_count above baseline data

# %%
b_stats
# Out:
#        PULocationID                    time_bucket    trip_count  \
# count  6.079392e+06                        6079392  6.079392e+06
# mean   1.456140e+02  2024-07-09 11:52:29.999988736  1.703395e+01
# min    4.000000e+00            2023-01-01 00:00:00  0.000000e+00
# 25%    8.800000e+01            2023-10-05 17:56:15  2.000000e+00
# 50%    1.430000e+02            2024-07-09 11:52:30  9.000000e+00
# 75%    2.110000e+02            2025-04-13 05:48:45  2.500000e+01
# max    2.630000e+02            2026-01-15 23:45:00  3.100000e+02
# std    7.191169e+01                            NaN  2.157228e+01
#
#                hour        minute     dayofweek    is_weekend         month  \
# count  6.079392e+06  6.079392e+06  6.079392e+06  6.079392e+06  6.079392e+06
# mean   1.150000e+01  2.250000e+01  2.997300e+00  2.853285e-01  6.447345e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %%
n_stats
# Out:
#         PULocationID                    time_bucket     trip_count  \
# count  250853.000000                         250853  250853.000000
# mean      143.539005  2026-02-07 10:57:57.438580224      78.672804
# min         4.000000            2026-01-16 00:00:00      -5.000000
# 25%        87.000000            2026-01-27 11:00:00       1.000000
# 50%       142.000000            2026-02-07 22:00:00       6.000000
# 75%       211.000000            2026-02-18 11:00:00      19.000000
# max       263.000000            2026-02-28 23:45:00   99999.000000
# std        72.804804                            NaN    2433.026184
#
#                 hour         minute      dayofweek     is_weekend  \
# count  250853.000000  250853.000000  250853.000000  250853.000000
# mean       11.500229      22.500448       3.065481       0.295077
# min         0.000000       0.000000       0.000000       0.000000
# 25%         6.000000      15.000000       1.000000       0.000000
# ...

# %%
key_columns = [
"PULocationID",
"time_bucket",
"trip_count",
"hour",
"minute",
"dayofweek",
"is_weekend",
"month",
"dayofyear",
"weekofyear",
"year",
"slot_of_day",
"is_holiday",
"cbd_pricing_active",
"borough_id",
"service_zone_id",
"is_airport_zone",
"zone_slot_baseline",
]
for col, count in baseline.isna().sum().items(): 
    if col in key_columns and count != 0: 
        print(f"Missing values for column {col}")

# %%
baseline.isna().sum()
# Out:
# PULocationID              0
# time_bucket               0
# trip_count                0
# hour                      0
# minute                    0
# dayofweek                 0
# is_weekend                0
# month                     0
# dayofyear                 0
# weekofyear                0
# year                      0
# slot_of_day               0
# hour_sin                  0
# hour_cos                  0
# dow_sin                   0
# dow_cos                   0
# month_sin                 0
# month_cos                 0
# is_holiday                0
# cbd_pricing_active        0
# borough_id                0
# service_zone_id           0
# is_airport_zone           0
# zone_slot_baseline        0
# lag_15min                57
# lag_1h                  228
# lag_2h                  456
# lag_1day               5472
# lag_1week             38304
# roll_mean_1h             57
# roll_mean_2h             57
# roll_mean_1day           57
# dtype: int64

# %%
from scipy.stats import ks_2samp

# %%
clipped_corrupted = corrupted[corrupted.trip_count < baseline.trip_count.max()]

# %%
baseline.trip_count.hist(bins=100)
# Out:
# <Axes: >

# %%
clipped_corrupted.trip_count.hist(bins=100)
# Out:
# <Axes: >

# %%
ks_2samp(baseline.trip_count, baseline.trip_count)
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=0, statistic_sign=1)

# %%
ks_2samp(baseline.trip_count, corrupted.trip_count)
# Out:
# KstestResult(statistic=0.07513749929648167, pvalue=0.0, statistic_location=5, statistic_sign=-1)

# %%
ks_2samp(baseline.trip_count, clipped_corrupted.trip_count)
# Out:
# KstestResult(statistic=0.07574533006454043, pvalue=0.0, statistic_location=5, statistic_sign=-1)

# %%
import numpy as np 

def compare(a, b): 
    """gpt-5.5-sourced ECDF plot utility fn"""
    result = ks_2samp(a, b)
    print(f"D = {result.statistic:.4f}")
    print(f"p = {result.pvalue:.4g}")

    def ecdf(x):
        x = np.sort(x)
        y = np.arange(1, len(x) + 1) / len(x)
        return x, y

    # Plot
    x1, y1 = ecdf(a)
    x2, y2 = ecdf(b)

    plt.figure(figsize=(8, 5))
    plt.plot(x1, y1, label="A")
    plt.plot(x2, y2, label="B")

    plt.xlabel("Feature Value")
    plt.ylabel("ECDF")
    plt.title(f"KS Statistic = {result.statistic:.3f}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
compare(new.trip_count, window.trip_count)
# Out:
# D = 0.1258
# p = 3.672e-38

# %%
import json
d = { "biz" : "bang" }
     
with open("foo.txt", "w") as foo: 
    json.dump(d, foo, default=str)

# %%
# !cat foo.txt
# Out:
# {"biz": "bang"}

# %%
from sklearn.metrics import accuracy_score

# %%
import random 
predictions = [int(random.random()) for _ in range(len(baseline))]
actuals = [int(random.random()) for _ in range(len(baseline))]

# %%
result = { }
temp_df = baseline.copy()
temp_df['actuals'] = actuals 
temp_df['predictions'] = predictions

for zone in temp_df.PULocationID.unique(): 
    zone_df = temp_df[temp_df.PULocationID == zone]
    result[str(zone)] = accuracy_score(zone_df.actuals, zone_df.predictions)

result
# Out:
# {'4': 1.0,
#  '13': 1.0,
#  '24': 1.0,
#  '41': 1.0,
#  '43': 1.0,
#  '45': 1.0,
#  '48': 1.0,
#  '50': 1.0,
#  '68': 1.0,
#  '70': 1.0,
#  '74': 1.0,
#  '75': 1.0,
#  '79': 1.0,
#  '87': 1.0,
#  '88': 1.0,
#  '90': 1.0,
#  '93': 1.0,
#  '100': 1.0,
#  '107': 1.0,
#  '113': 1.0,
#  '114': 1.0,
#  '125': 1.0,
#  '132': 1.0,
#  '137': 1.0,
#  '138': 1.0,
#  '140': 1.0,
#  '141': 1.0,
#  '142': 1.0,
#  '143': 1.0,
#  '144': 1.0,
#  '148': 1.0,
#  '151': 1.0,
#  '158': 1.0,
#  '161': 1.0,
#  '162': 1.0,
#  '163': 1.0,
#  '164': 1.0,
#  '166': 1.0,
#  '170': 1.0,
#  '186': 1.0,
#  '195': 1.0,
#  '209': 1.0,
#  '211': 1.0,
#  '229': 1.0,
#  '230': 1.0,
#  '231': 1.0,
#  '233': 1.0,
#  '234': 1.0,
#  '236': 1.0,
#  '237': 1.0,
#  '238': 1.0,
#  '239': 1.0,
#  '246': 1.0,
#  '249': 1.0,
#  '261': 1.0,
#  '262': 1.0,
#  '263': 1.0}

# %%
type(baseline.PULocationID.unique()[0])
# Out:
# numpy.int64

# %%
res = baseline.isna().mean()

# %%
res[0]
# Out:
# /var/folders/t0/vjz2r6l1155639x6cpfr8z3h0000gn/T/ipykernel_96505/4265798342.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   res[0]
# 0.0

# %%
results = {}
for i in res.items(): 
    results[i[0]] = i[1]

# %%
results
# Out:
# {'PULocationID': 0.0,
#  'time_bucket': 0.0,
#  'trip_count': 0.0,
#  'hour': 0.0,
#  'minute': 0.0,
#  'dayofweek': 0.0,
#  'is_weekend': 0.0,
#  'month': 0.0,
#  'dayofyear': 0.0,
#  'weekofyear': 0.0,
#  'year': 0.0,
#  'slot_of_day': 0.0,
#  'hour_sin': 0.0,
#  'hour_cos': 0.0,
#  'dow_sin': 0.0,
#  'dow_cos': 0.0,
#  'month_sin': 0.0,
#  'month_cos': 0.0,
#  'is_holiday': 0.0,
#  'cbd_pricing_active': 0.0,
#  'borough_id': 0.0,
#  'service_zone_id': 0.0,
#  'is_airport_zone': 0.0,
#  'zone_slot_baseline': 0.0,
#  'lag_15min': 9.375937593759377e-06,
#  'lag_1h': 3.750375037503751e-05,
#  'lag_2h': 7.500750075007501e-05,
#  'lag_1day': 0.0009000900090009,
#  'lag_1week': 0.0063006300630063005,
#  'roll_mean_1h': 9.375937593759377e-06,
#  'roll_mean_2h': 9.375937593759377e-06,
#  'roll_mean_1day': 9.375937593759377e-06}

# %%
new = pd.read_parquet("../week4/data/demand_enriched_week4.parquet")

# %%
new.head()
# Out:
#    PULocationID         time_bucket  trip_count  hour  minute  dayofweek  \
# 0             4 2023-01-01 00:00:00           1     0       0          6
# 1             4 2023-01-01 00:15:00           4     0      15          6
# 2             4 2023-01-01 00:30:00           4     0      30          6
# 3             4 2023-01-01 00:45:00           5     0      45          6
# 4             4 2023-01-01 01:00:00           4     1       0          6
#
#    is_weekend  month  dayofyear  weekofyear  ...  is_airport_zone  \
# 0           1      1          1          52  ...                0
# 1           1      1          1          52  ...                0
# 2           1      1          1          52  ...                0
# 3           1      1          1          52  ...                0
# 4           1      1          1          52  ...                0
#
#    zone_slot_baseline  lag_15min  lag_1h  lag_2h  lag_1day  lag_1week  \
# ...

# %%
new.columns
# Out:
# Index(['PULocationID', 'time_bucket', 'trip_count', 'hour', 'minute',
#        'dayofweek', 'is_weekend', 'month', 'dayofyear', 'weekofyear', 'year',
#        'slot_of_day', 'hour_sin', 'hour_cos', 'dow_sin', 'dow_cos',
#        'month_sin', 'month_cos', 'is_holiday', 'cbd_pricing_active',
#        'borough_id', 'service_zone_id', 'is_airport_zone',
#        'zone_slot_baseline', 'lag_15min', 'lag_1h', 'lag_2h', 'lag_1day',
#        'lag_1week', 'roll_mean_1h', 'roll_mean_2h', 'roll_mean_1day'],
#       dtype='object')

# %%
latest = new["time_bucket"].max()
window_start = latest - pd.Timedelta(hours=12)

# %%
window = new[new.time_bucket > window_start]

# %%
window.describe()
# Out:
#        PULocationID                    time_bucket   trip_count         hour  \
# count   2736.000000                           2736  2736.000000  2736.000000
# mean     145.614035  2026-02-28 17:52:30.000000256    16.242325    17.500000
# min        4.000000            2026-02-28 12:00:00     0.000000    12.000000
# 25%       88.000000            2026-02-28 14:56:15     4.000000    14.750000
# 50%      143.000000            2026-02-28 17:52:30    12.500000    17.500000
# 75%      211.000000            2026-02-28 20:48:45    23.000000    20.250000
# max      263.000000            2026-02-28 23:45:00   113.000000    23.000000
# std       71.924825                            NaN    15.558774     3.452684
#
#             minute  dayofweek  is_weekend   month  dayofyear  weekofyear  ...  \
# count  2736.000000     2736.0      2736.0  2736.0     2736.0      2736.0  ...
# mean     22.500000        5.0         1.0     2.0       59.0         9.0  ...
# ...

# %%
window.head(10)
# Out:
#         PULocationID         time_bucket  trip_count  hour  minute  dayofweek  \
# 110832             4 2026-02-28 12:00:00           0    12       0          5
# 110833             4 2026-02-28 12:15:00           0    12      15          5
# 110834             4 2026-02-28 12:30:00           0    12      30          5
# 110835             4 2026-02-28 12:45:00           0    12      45          5
# 110836             4 2026-02-28 13:00:00           0    13       0          5
# 110837             4 2026-02-28 13:15:00           0    13      15          5
# 110838             4 2026-02-28 13:30:00           0    13      30          5
# 110839             4 2026-02-28 13:45:00           0    13      45          5
# 110840             4 2026-02-28 14:00:00           0    14       0          5
# 110841             4 2026-02-28 14:15:00           0    14      15          5
#
#         is_weekend  month  dayofyear  weekofyear  ...  is_airport_zone  \
# ...

# %%
from ..week3.backend.data import forecast_demand
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 from ..week3.backend.data import forecast_demand
#
# ImportError: attempted relative import with no known parent package

# %%
r = None
for _, row in window.iterrows(): 
    r = row
    break

# %%
FEATURES = [
    "PULocationID",
    "hour",
    "minute",
    "dayofweek",
    "is_weekend",
    "month",
    "dayofyear",
    "weekofyear",
    "year",
    "slot_of_day",
    "hour_sin",
    "hour_cos",
    "dow_sin",
    "dow_cos",
    "month_sin",
    "month_cos",
    "is_holiday",
    "cbd_pricing_active",
    "is_airport_zone",
    "borough_id",
    "service_zone_id",
    "zone_slot_baseline",
    "lag_15min",
    "lag_1h",
    "lag_2h",
    "lag_1day",
    "lag_1week",
    "roll_mean_1h",
    "roll_mean_2h",
    "roll_mean_1day",
]

# %%
window[FEATURES].columns
# Out:
# Index(['PULocationID', 'hour', 'minute', 'dayofweek', 'is_weekend', 'month',
#        'dayofyear', 'weekofyear', 'year', 'slot_of_day', 'hour_sin',
#        'hour_cos', 'dow_sin', 'dow_cos', 'month_sin', 'month_cos',
#        'is_holiday', 'cbd_pricing_active', 'is_airport_zone', 'borough_id',
#        'service_zone_id', 'zone_slot_baseline', 'lag_15min', 'lag_1h',
#        'lag_2h', 'lag_1day', 'lag_1week', 'roll_mean_1h', 'roll_mean_2h',
#        'roll_mean_1day'],
#       dtype='object')

# %%
window.columns
# Out:
# Index(['PULocationID', 'time_bucket', 'trip_count', 'hour', 'minute',
#        'dayofweek', 'is_weekend', 'month', 'dayofyear', 'weekofyear', 'year',
#        'slot_of_day', 'hour_sin', 'hour_cos', 'dow_sin', 'dow_cos',
#        'month_sin', 'month_cos', 'is_holiday', 'cbd_pricing_active',
#        'borough_id', 'service_zone_id', 'is_airport_zone',
#        'zone_slot_baseline', 'lag_15min', 'lag_1h', 'lag_2h', 'lag_1day',
#        'lag_1week', 'roll_mean_1h', 'roll_mean_2h', 'roll_mean_1day'],
#       dtype='object')

# %%
MODEL_PATH = "../week2/model/lgbm_demand_model.txt"

import lightgbm as lgb
print("Loading model...")  
model = lgb.Booster(model_file=str(MODEL_PATH))
# Out:
# Loading model...

# %%
preds = model.predict(window[FEATURES])

# %%
len(preds) == len(window)
# Out:
# True

# %%
preds = max(0.0, preds)  # Clip to non-negative
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 preds = max(0.0, preds)  # Clip to non-negative
#
# TypeError: 'numpy.float64' object is not callable

# %%
preds[2] = -0.3

# %%
preds[preds < 0] = 0

# %%
preds
# Out:
# array([ 0.48598482,  0.49179388,  0.        , ..., 23.94567496,
#        22.45779208, 19.10423791])

# %%
np.int32(preds)
# Out:
# array([ 0,  0,  0, ..., 23, 22, 19], dtype=int32)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(window.trip_count,preds)
# Out:
# 6.006040395741087

# %%
window.trip_count - preds
# Out:
# 110832     -0.485985
# 110833     -0.491794
# 110834      0.000000
# 110835     -0.568404
# 110836     -0.553373
#              ...
# 6320155   -11.770882
# 6320156     2.019919
# 6320157    -4.945675
# 6320158    -7.457792
# 6320159     4.895762
# Name: trip_count, Length: 2736, dtype: float64

# %%
window.describe()
# Out:
#        PULocationID                    time_bucket   trip_count         hour  \
# count   2736.000000                           2736  2736.000000  2736.000000
# mean     145.614035  2026-02-28 17:52:30.000000256    16.242325    17.500000
# min        4.000000            2026-02-28 12:00:00     0.000000    12.000000
# 25%       88.000000            2026-02-28 14:56:15     4.000000    14.750000
# 50%      143.000000            2026-02-28 17:52:30    12.500000    17.500000
# 75%      211.000000            2026-02-28 20:48:45    23.000000    20.250000
# max      263.000000            2026-02-28 23:45:00   113.000000    23.000000
# std       71.924825                            NaN    15.558774     3.452684
#
#             minute  dayofweek  is_weekend   month  dayofyear  weekofyear  ...  \
# count  2736.000000     2736.0      2736.0  2736.0     2736.0      2736.0  ...
# mean     22.500000        5.0         1.0     2.0       59.0         9.0  ...
# ...

# %%
np.std(preds)
# Out:
# 17.376344246473643

# %%
window.isna()
# Out:
#          PULocationID  time_bucket  trip_count   hour  minute  dayofweek  \
# 110832          False        False       False  False   False      False
# 110833          False        False       False  False   False      False
# 110834          False        False       False  False   False      False
# 110835          False        False       False  False   False      False
# 110836          False        False       False  False   False      False
# ...               ...          ...         ...    ...     ...        ...
# 6320155         False        False       False  False   False      False
# 6320156         False        False       False  False   False      False
# 6320157         False        False       False  False   False      False
# 6320158         False        False       False  False   False      False
# 6320159         False        False       False  False   False      False
#
#          is_weekend  month  dayofyear  weekofyear  ...  is_airport_zone  \
# ...

# %%
from matplotlib import pyplot as plt
for col in baseline.columns:
  fig, axes = plt.subplots(1, 2, figsize=(8, 1))
  axes[0].hist(baseline[col], bins=20)
  axes[1].hist(new[col], bins=20)
  axes[0].set_title(f"Baseline {col}")
  axes[1].set_title(f"Window {col}")
  plt.show()

# %%
group_df = baseline.groupby(['hour'])

# %%
group_df.mean()
# Out:
#       PULocationID                   time_bucket  trip_count  minute  \
# hour
# 0       145.614035 2024-07-09 00:22:30.000000000   10.988919    22.5
# 1       145.614035 2024-07-09 01:22:30.000000000    7.197676    22.5
# 2       145.614035 2024-07-09 02:22:30.000000000    4.662798    22.5
# 3       145.614035 2024-07-09 03:22:30.000000000    2.981177    22.5
# 4       145.614035 2024-07-09 04:22:30.000000000    1.860703    22.5
# 5       145.614035 2024-07-09 05:22:30.000000000    2.064570    22.5
# 6       145.614035 2024-07-09 06:22:30.000000256    4.959500    22.5
# 7       145.614035 2024-07-09 07:22:30.000000000   10.314135    22.5
# 8       145.614035 2024-07-09 08:22:30.000000000   14.623285    22.5
# 9       145.614035 2024-07-09 09:22:30.000000000   17.111315    22.5
# 10      145.614035 2024-07-09 10:22:30.000000000   18.967759    22.5
# 11      145.614035 2024-07-09 11:22:30.000000000   20.621627    22.5
# ...

# %%
new.columns
# Out:
# Index(['PULocationID', 'time_bucket', 'trip_count', 'hour', 'minute',
#        'dayofweek', 'is_weekend', 'month', 'dayofyear', 'weekofyear', 'year',
#        'slot_of_day', 'hour_sin', 'hour_cos', 'dow_sin', 'dow_cos',
#        'month_sin', 'month_cos', 'is_holiday', 'cbd_pricing_active',
#        'borough_id', 'service_zone_id', 'is_airport_zone',
#        'zone_slot_baseline', 'lag_15min', 'lag_1h', 'lag_2h', 'lag_1day',
#        'lag_1week', 'roll_mean_1h', 'roll_mean_2h', 'roll_mean_1day'],
#       dtype='object')

# %%
new.PULocationID.unique()
# Out:
# array([  4,  13,  24,  41,  43,  45,  48,  50,  68,  70,  74,  75,  79,
#         87,  88,  90,  93, 100, 107, 113, 114, 125, 132, 137, 138, 140,
#        141, 142, 143, 144, 148, 151, 158, 161, 162, 163, 164, 166, 170,
#        186, 195, 209, 211, 229, 230, 231, 233, 234, 236, 237, 238, 239,
#        246, 249, 261, 262, 263])

# %%
group_df2 = new.groupby(["PULocationID"])

# %%
group_df2.mean()
# Out:
#                      time_bucket  trip_count  hour  minute  dayofweek  \
# PULocationID
# 4            2024-07-31 11:52:30    1.070680  11.5    22.5        3.0
# 13           2024-07-31 11:52:30    5.720121  11.5    22.5        3.0
# 24           2024-07-31 11:52:30    2.291396  11.5    22.5        3.0
# 41           2024-07-31 11:52:30    1.946744  11.5    22.5        3.0
# 43           2024-07-31 11:52:30   16.220617  11.5    22.5        3.0
# 45           2024-07-31 11:52:30    1.339168  11.5    22.5        3.0
# 48           2024-07-31 11:52:30   25.382657  11.5    22.5        3.0
# 50           2024-07-31 11:52:30    5.518732  11.5    22.5        3.0
# 68           2024-07-31 11:52:30   26.729338  11.5    22.5        3.0
# 70           2024-07-31 11:52:30    3.945346  11.5    22.5        3.0
# 74           2024-07-31 11:52:30    1.751533  11.5    22.5        3.0
# 75           2024-07-31 11:52:30    5.359903  11.5    22.5        3.0
# ...

# %%
def error_by_ordinal(df, col='PULocationID', n=1000):
    """
    Calculate the error for a specific ordinal value, based on provided number of samples 
    per ordinal value 
    """
    groups = df.groupby(col)
    df_sample = groups.sample(n=n)
    preds = [random.random() for _ in range(len(df_sample))]
    df_sample_small = df_sample[[col, 'trip_count']].copy()
    df_sample_small['preds'] = preds 
    df_sample_small['error'] = abs(df_sample_small['trip_count'] - preds) 
    
    return df_sample_small.groupby(col).mean()

# %%
baseline_loc_error = error_by_ordinal(baseline, col='PULocationID')
new_loc_error = error_by_ordinal(new, col='PULocationID')

# %%
baseline_loc_error.head()
# Out:
#               trip_count     preds      error
# PULocationID
# 4                  1.079  0.495986   1.150199
# 13                 5.816  0.502800   5.546636
# 24                 2.326  0.508182   2.093270
# 41                 1.955  0.512374   1.752754
# 43                15.281  0.504997  14.958671

# %%
new_loc_error.head()
# Out:
#               trip_count     preds      error
# PULocationID
# 4                  1.046  0.499819   1.149020
# 13                 5.265  0.497382   5.025762
# 24                 2.301  0.504083   2.097868
# 41                 1.934  0.483658   1.720909
# 43                16.045  0.507693  15.715130

# %%
baseline_it = baseline_loc_error.reset_index(0).iterrows()
new_it = new_loc_error.reset_index(0).iterrows()

for baseline_row, new_row in zip(baseline_it, new_it):     
    assert baseline_row[1].PULocationID == new_row[1].PULocationID
    print(baseline_row[1].error, "< baseline | new >", new_row[1].error)
    break
# Out:
# 1.1501993015160983 < baseline | new > 1.1490204609706427
